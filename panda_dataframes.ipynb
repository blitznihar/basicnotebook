# %% [markdown]
# # Pandas Dataframes

# %% [markdown]
# ### Definition: series that share same index

# %%
import numpy as np
import pandas as pd

url = 'https://www.usda.gov/sites/default/files/documents/data.json'
agridata = pd.read_json(url)

# %% [markdown]
# ### Normalizing JSON data

# %%
moredata = pd.json_normalize(agridata['dataset'], 
                            record_path ='distribution')

# %% [markdown]
# ### Getting column Names abd types

# %%
moredata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   @type            4812 non-null   object
#  1   downloadURL      2854 non-null   object
#  2   mediaType        4576 non-null   object
#  3   title            2543 non-null   object
#  4   describedBy      7 non-null      object
#  5   conformsTo       1 non-null      object
#  6   describedByType  5 non-null      object
#  7   description      332 non-null    object
#  8   accessURL        1958 non-null   object
#  9   format           4062 non-null   object
# dtypes: object(10)
# memory usage: 376.1+ KB

# %% [markdown]
# ### Select top few rows

# %%
moredata.head(4)
# Out:
#                @type                                        downloadURL  \
# 0  dcat:Distribution  http://www.dm.usda.gov/foia/docs/Copy%20of%20E...
# 1  dcat:Distribution                  http://www.usda.gov/data-edi.json
# 2  dcat:Distribution  http://www.usda.gov/wps/portal/usda/usdahome?c...
# 3  dcat:Distribution  http://www.usda.gov/digitalstrategy/costsaving...
#
#                   mediaType  \
# 0  application/vnd.ms-excel
# 1          application/json
# 2  application/vnd.ms-excel
# 3          application/json
#
#                                                title  \
# 0            Congressional Logs for Fiscal Year 2014
# 1                                                NaN
# 2  Department of Agriculture Secretary's Calendar...
# 3                                                NaN
#
#                                          describedBy  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://management.cio.gov/schemaexamples/cost...
#
#                            conformsTo   describedByType description accessURL  \
# 0                                 NaN               NaN         NaN       NaN
# 1                                 NaN               NaN         NaN       NaN
# 2                                 NaN               NaN         NaN       NaN
# 3  https://management.cio.gov/schema/  application/json         NaN       NaN
#
#   format
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN

# %% [markdown]
# ### Selecting specific Columns and renaming the columns

# %%
moredata = moredata[['title','@type','downloadURL','mediaType']].fillna('NA').rename(columns={'title': 'Title','@type': 'Type', 'downloadURL': 'url'}) 
moredata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      4812 non-null   object
#  1   Type       4812 non-null   object
#  2   url        4812 non-null   object
#  3   mediaType  4812 non-null   object
# dtypes: object(4)
# memory usage: 150.5+ KB

# %% [markdown]
# ### filtering down columns further

# %%
moredata = moredata[['Title','url']]
moredata.info() 
moredata.head(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   4812 non-null   object
#  1   url     4812 non-null   object
# dtypes: object(2)
# memory usage: 75.3+ KB
#                                                 Title  \
# 0             Congressional Logs for Fiscal Year 2014
# 1                                                  NA
# 2   Department of Agriculture Secretary's Calendar...
# 3                                                  NA
# 4                                          March 2014
# 5                             2013 FOIA Annual Report
# 6                        2013 USDA FOIA Annual Report
# 7             USDA IT Bureau Leadership JSON download
# 8                                   Governance Boards
# 9                                      USDA IT Policy
# 10                                           Report 1
# 11                                           Report 2
# 12                                           Report 3
# 13            Query tool - Farm structure and finance
# 14             Query tool - Crop production practices
# 15                                          Data file
# 16                Ag and Food Sectors and the Economy
# 17                         Land and Natural Resources
# 18                            Farming and Farm Income
# 19                                      Rural Economy
# 20                 Agricultural Production and Prices
# 21                                 Agricultural Trade
# 22                  Food Availability and Consumption
# 23                           Food Prices and Spending
# 24             Food Security and Nutrition Assistance
# 25                                         Query tool
# 26                 Web page with links to Excel files
# 27                 Web page with links to Excel files
# 28                                          Data file
# 29  Detailed ERS Producer and Port Multipliers by ...
# 30                                  Online calculator
# 31                     ZIP file of CSV formatted data
# 32                      Web page links to Excel files
# 33                                          Data file
# 34                                   GIS API Services
# 35                                    Interactive map
# 36                                   Zip of CSV files
# 37                                      Chart gallery
# 38                                      Chart gallery
# 39                                      Chart gallery
# 40                                      Chart gallery
# 41                        Best of Charts of Note 2017
# 42                                            Gallery
# 43                          Gallery of charts of note
# 44                                         Query tool
# 45                 Web page with links to Excel files
# 46                 Web page with links to Excel files
# 47                                         Query tool
# 48                Demand Elasticities from Literature
# 49                                 Data download page
#
#                                                   url
# 0   http://www.dm.usda.gov/foia/docs/Copy%20of%20E...
# 1                   http://www.usda.gov/data-edi.json
# 2   http://www.usda.gov/wps/portal/usda/usdahome?c...
# 3   http://www.usda.gov/digitalstrategy/costsaving...
# 4   http://www.dm.usda.gov/procurement/ccsc/docs/F...
# 5   http://www.dm.usda.gov/foia/docs/USDA.FY13.Fin...
# 6   http://www.dm.usda.gov/foia/docs/USDA%20FY13%2...
# 7   http://www.usda.gov/digitalstrategy/bureaudire...
# 8   http://www.usda.gov/digitalstrategy/governance...
# 9   http://www.usda.gov/digitalstrategy/policyarch...
# 10                http://www.dm.usda.gov/R162105A.XLS
# 11                http://www.dm.usda.gov/R162105B.XLS
# 12                http://www.dm.usda.gov/R162105C.XLS
# 13  http://www.ers.usda.gov/data-products/arms-far...
# 14  http://www.ers.usda.gov/data-products/arms-far...
# 15  http://www.ers.usda.gov/data-products/adoption...
# 16  http://www.ers.usda.gov/data-products/ag-and-f...
# 17  http://www.ers.usda.gov/data-products/ag-and-f...
# 18  http://www.ers.usda.gov/data-products/ag-and-f...
# 19  http://www.ers.usda.gov/data-products/ag-and-f...
# 20  http://www.ers.usda.gov/data-products/ag-and-f...
# 21  http://www.ers.usda.gov/data-products/ag-and-f...
# 22  http://www.ers.usda.gov/data-products/ag-and-f...
# 23  http://www.ers.usda.gov/data-products/ag-and-f...
# 24  http://www.ers.usda.gov/data-products/ag-and-f...
# 25  http://www.ers.usda.gov/data-products/agricult...
# 26  http://www.ers.usda.gov/data-products/agricult...
# 27  http://www.ers.usda.gov/data-products/agricult...
# 28                                                 NA
# 29  http://www.ers.usda.gov/dataFiles/ATMCalculato...
# 30  http://www.ers.usda.gov/data-products/agricult...
# 31  https://www.ers.usda.gov/data-products/aquacul...
# 32  http://www.ers.usda.gov/data-products/aquacult...
# 33  https://www.ers.usda.gov/data-products/atlas-o...
# 34                                                 NA
# 35  http://www.ers.usda.gov/data-products/atlas-of...
# 36  https://www.ers.usda.gov/data-products/atlas-o...
# 37                                                 NA
# 38                                                 NA
# 39                                                 NA
# 40                                                 NA
# 41  https://www.ers.usda.gov/data-products/best-of...
# 42  http://www.ers.usda.gov/data-products/chart-ga...
# 43  http://www.ers.usda.gov/data-products/charts-o...
# 44                                                 NA
# 45  http://www.ers.usda.gov/data-products/commodit...
# 46  http://www.ers.usda.gov/data-products/commodit...
# 47                                                 NA
# 48                                                 NA
# 49                                                 NA

# %% [markdown]
# ### Know number of rows and columns

# %%
moredata.shape

# %% [markdown]
# ### filtering rows

# %%
moredata= moredata[moredata['Title'].str.contains('Prices', case=True, regex=False)]
moredata
# Out:
#                                                   Title  \
# 20                   Agricultural Production and Prices
# 23                             Food Prices and Spending
# 122                Quarterly Food-Away-From-Home Prices
# 2428  Brazilian Soybean Export Truck Transportation ...
#
#                                                     url
# 20    http://www.ers.usda.gov/data-products/ag-and-f...
# 23    http://www.ers.usda.gov/data-products/ag-and-f...
# 122                                                  NA
# 2428  http://www.ams.usda.gov/sites/default/files/me...

# %%
moredata.shape
fooddataurl = moredata[moredata['Title'].str.contains('spending', case=False)]['url']
pd.options.display.max_colwidth = 900 
print(fooddataurl)
# Out:
# 23    http://www.ers.usda.gov/data-products/ag-and-food-statistics-charting-the-essentials/food-prices-and-spending.aspx
# Name: url, dtype: object
